# %%
import numpy as np
import matplotlib.pyplot as plt

from LuaLoader import EMU_Process as EMU

# %%
_, result = EMU.create_and_run(("Joe", "no args"))

# %%
pic = np.array(result["pic"])
pic.shape
# Out:
# (230, 199, 3)

# %%
plt.imshow(pic)

# %%
230*199*3
# Out:
# 137310
